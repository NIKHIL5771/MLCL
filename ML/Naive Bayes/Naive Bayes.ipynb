# %%
import pandas as pd
import numpy as np

# %%
salary_train = pd.read_csv(r"C:\Users\rajni\Desktop\MLOBA\SalaryData_Train.csv")
salary_test = pd.read_csv(r"C:\Users\rajni\Desktop\MLOBA\SalaryData_Test.csv")

# %%
salary_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
salary_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
salary_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
salary_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_train.skew()
# Out:
# C:\Users\rajni\AppData\Local\Temp\ipykernel_5312\3242279717.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   salary_train.skew()
# age              0.530180
# educationno     -0.305378
# capitalgain     11.902483
# capitalloss      4.528238
# hoursperweek     0.330856
# dtype: float64

# %%
salary_test.skew()
# Out:
# C:\Users\rajni\AppData\Local\Temp\ipykernel_5312\3342015606.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   salary_test.skew()
# age              0.536112
# educationno     -0.320999
# capitalgain     11.570156
# capitalloss      4.496738
# hoursperweek     0.359502
# dtype: float64

# %%
salary_train.kurtosis()
# Out:
# C:\Users\rajni\AppData\Local\Temp\ipykernel_5312\2695462535.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   salary_train.kurtosis()
# age              -0.144760
# educationno       0.643605
# capitalgain     153.661174
# capitalloss      19.529284
# hoursperweek      3.167683
# dtype: float64

# %%
salary_test.kurtosis()
# Out:
# C:\Users\rajni\AppData\Local\Temp\ipykernel_5312\3980991936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   salary_test.kurtosis()
# age              -0.181312
# educationno       0.618468
# capitalgain     143.591390
# capitalloss      19.080685
# hoursperweek      3.267311
# dtype: float64

# %%
import seaborn as sns

# %%
salary_train.shape
# Out:
# (30161, 14)

# %%
salary_test.shape
# Out:
# (15060, 14)

# %%
salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_train1=salary_train.drop('educationno',axis=1)

# %%
salary_train1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
str_col=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
for i in str_col:
    salary_train1[i]=labelencoder.fit_transform(salary_train1[i])

# %%
salary_train1.head(20)
# Out:
#     age  workclass  education  maritalstatus  occupation  relationship  race  \
# 0    39          5          9              4           0             1     4
# 1    50          4          9              2           3             0     4
# 2    38          2         11              0           5             1     4
# 3    53          2          1              2           5             0     2
# 4    28          2          9              2           9             5     2
# 5    37          2         12              2           3             5     4
# 6    49          2          6              3           7             1     2
# 7    52          4         11              2           3             0     4
# 8    31          2         12              4           9             1     4
# 9    42          2          9              2           3             0     4
# 10   37          2         15              2           3             0     2
# 11   30          5          9              2           9             0     1
# 12   23          2          9              4           0             3     4
# 13   32          2          7              4          11             1     2
# 14   34          2          5              2          13             0     0
# 15   25          4         11              4           4             3     4
# 16   32          2         11              4           6             4     4
# 17   38          2          1              2          11             0     4
# 18   43          4         12              0           3             4     4
# 19   40          2         10              2           9             0     4
#
#     sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0     1         2174            0            40      37   <=50K
# 1     1            0            0            13      37   <=50K
# 2     1            0            0            40      37   <=50K
# 3     1            0            0            40      37   <=50K
# 4     0            0            0            40       4   <=50K
# 5     0            0            0            40      37   <=50K
# 6     0            0            0            16      21   <=50K
# 7     1            0            0            45      37    >50K
# 8     0        14084            0            50      37    >50K
# 9     1         5178            0            40      37    >50K
# 10    1            0            0            80      37    >50K
# 11    1            0            0            40      17    >50K
# 12    0            0            0            30      37   <=50K
# 13    1            0            0            50      37   <=50K
# 14    1            0            0            45      24   <=50K
# 15    1            0            0            35      37   <=50K
# 16    1            0            0            40      37   <=50K
# 17    1            0            0            50      37   <=50K
# 18    0            0            0            45      37    >50K
# 19    1            0            0            60      37    >50K

# %%
salary_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
salary_test1=salary_test.drop('educationno',axis=1)

# %%
salary_test1.columns
# Out:
# Index(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
str_col1=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
sns.boxplot(x="age", y="education", data=salary_test1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='education'>

# %%
sns.boxplot(x="sex", y="age", data=salary_train1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
salary_test1.plot(kind="scatter", x="workclass", y="age")
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='age'>

# %%
sns.violinplot(x="sex", y="education", data=salary_train1, size=6)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='education'>

# %%
sns.violinplot(x="age", y="maritalstatus", data=salary_test1, size=6)
# Out:
# <AxesSubplot:xlabel='age', ylabel='maritalstatus'>

# %%
salary_test1.skew()
# Out:
# C:\Users\rajni\AppData\Local\Temp\ipykernel_5312\1037082089.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   salary_test1.skew()
# age              0.536112
# capitalgain     11.570156
# capitalloss      4.496738
# hoursperweek     0.359502
# dtype: float64

# %%
sns.pairplot(salary_test1)

# %%
for i in str_col1:
    salary_test1[i]=labelencoder.fit_transform(salary_test1[i])

# %%
salary_train1.shape
# Out:
# (30161, 13)

# %%
salary_test1.shape
# Out:
# (15060, 13)

# %%
salary_train1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  int32
#  2   education      30161 non-null  int32
#  3   maritalstatus  30161 non-null  int32
#  4   occupation     30161 non-null  int32
#  5   relationship   30161 non-null  int32
#  6   race           30161 non-null  int32
#  7   sex            30161 non-null  int32
#  8   capitalgain    30161 non-null  int64
#  9   capitalloss    30161 non-null  int64
#  10  hoursperweek   30161 non-null  int64
#  11  native         30161 non-null  int32
#  12  Salary         30161 non-null  object
# dtypes: int32(8), int64(4), object(1)
# memory usage: 2.1+ MB

# %%
salary_test1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  int32
#  2   education      15060 non-null  int32
#  3   maritalstatus  15060 non-null  int32
#  4   occupation     15060 non-null  int32
#  5   relationship   15060 non-null  int32
#  6   race           15060 non-null  int32
#  7   sex            15060 non-null  int32
#  8   capitalgain    15060 non-null  int64
#  9   capitalloss    15060 non-null  int64
#  10  hoursperweek   15060 non-null  int64
#  11  native         15060 non-null  int32
#  12  Salary         15060 non-null  object
# dtypes: int32(8), int64(4), object(1)
# memory usage: 1.0+ MB

# %%
Xtrain = salary_train1.iloc[: ,0:12]

# %%
Xtrain
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       39          5          9              4           0             1
# 1       50          4          9              2           3             0
# 2       38          2         11              0           5             1
# 3       53          2          1              2           5             0
# 4       28          2          9              2           9             5
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# 0         4    1         2174            0            40      37
# 1         4    1            0            0            13      37
# 2         4    1            0            0            40      37
# 3         2    1            0            0            40      37
# 4         2    0            0            0            40       4
# ...     ...  ...          ...          ...           ...     ...
# 30156     4    0            0            0            38      37
# 30157     4    1            0            0            40      37
# 30158     4    0            0            0            40      37
# 30159     4    1            0            0            20      37
# 30160     4    0        15024            0            40      37
#
# [30161 rows x 12 columns]

# %%
Ytrain = salary_train1.iloc[: , 12]

# %%
Ytrain
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
Xtest = salary_test1.iloc[ : ,0:12]

# %%
Xtest
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       25          2          1              4           6             3
# 1       38          2         11              2           4             0
# 2       28          1          7              2          10             0
# 3       44          2         15              2           6             0
# 4       34          2          0              4           7             1
# ...    ...        ...        ...            ...         ...           ...
# 15055   33          2          9              4           9             3
# 15056   39          2          9              0           9             1
# 15057   38          2          9              2           9             0
# 15058   44          2          9              0           0             3
# 15059   35          3          9              2           3             0
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# 0         2    1            0            0            40      37
# 1         4    1            0            0            50      37
# 2         4    1            0            0            40      37
# 3         2    1         7688            0            40      37
# 4         4    1            0            0            30      37
# ...     ...  ...          ...          ...           ...     ...
# 15055     4    1            0            0            40      37
# 15056     4    0            0            0            36      37
# 15057     4    1            0            0            50      37
# 15058     1    1         5455            0            40      37
# 15059     4    1            0            0            60      37
#
# [15060 rows x 12 columns]

# %%
Ytest = salary_test1.iloc[ : ,12]

# %%
Ytest
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 15060, dtype: object

# %%
from sklearn.naive_bayes import MultinomialNB as MB
from sklearn.naive_bayes import GaussianNB as GB

# %%
salary_MB = MB()

# %%
salary_MB.fit(Xtrain,Ytrain)
# Out:
# MultinomialNB()

# %%
y_pred = salary_MB.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 77.49667994687915

# %%
confusion_matrix(Ytest, y_pred)
# Out:
# array([[10891,   469],
#        [ 2920,   780]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.79      0.96      0.87     11360
#         >50K       0.62      0.21      0.32      3700
#
#     accuracy                           0.77     15060
#    macro avg       0.71      0.58      0.59     15060
# weighted avg       0.75      0.77      0.73     15060

# %%
salary_GB = GB()

# %%
salary_GB.fit(Xtrain,Ytrain)
# Out:
# GaussianNB()

# %%
y_pred = salary_GB.predict(Xtest)

# %%
acc = accuracy_score(Ytest, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 79.15006640106242

# %%
confusion_matrix(Ytest, y_pred)
# Out:
# array([[10784,   576],
#        [ 2564,  1136]], dtype=int64)

# %%
print(classification_report(Ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.81      0.95      0.87     11360
#         >50K       0.66      0.31      0.42      3700
#
#     accuracy                           0.79     15060
#    macro avg       0.74      0.63      0.65     15060
# weighted avg       0.77      0.79      0.76     15060
